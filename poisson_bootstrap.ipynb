# %% [markdown]
# ### Load libraries and functions

# %%
# load libraries
# %run _libraries.ipynb

# %%
# load functions
# %run _functions_load.ipynb

# %%
# start stopwatch
start = stopwatch_start()

# %%
dir_save_img = 'img/'

# %% [markdown]
# ## Poisson Bootstrap example

# %% [markdown]
# ### Normals with mean in 100 and 95 with 10000 elements

# %%
a = np.random.normal(100, 5, 1000)

# %%
fig = plt.figure(figsize=(8, 2))
plt.hist(a, bins=50, color=alpha_color(palette[1], 0.85))
plt.xlim(70, 120)
axis_rstyle()
plt.show()
savefig('a', dir=dir_save_img)
# Out:
# Images 'a.png' and 'a.svg' successfully saved into 'img/' directory

# %%
b = np.random.normal(95, 5, 1000)

# %%
fig = plt.figure(figsize=(8, 2))
plt.hist(b, bins=50, color=alpha_color(palette[2], 0.8));
plt.xlim(70, 120)
axis_rstyle()
plt.show()
savefig('b', dir=dir_save_img)
# Out:
# Images 'b.png' and 'b.svg' successfully saved into 'img/' directory

# %%
test_poisson_bootstrap(
    data1=a,
    data2=b,
    colors=[palette[1], palette[2]])
# Out:
#           Significantly difference:             False              Lower Boundary:      -3.707
#           Means Differences' distribution:     normal              Means Difference:     5.005
#           Kolmogorov–Smirnov test p-value:      0.959              Upper Boundary:      13.613
#
#           ====================================================================================
#
#           Sample 1 mean: 99.902
#           Sample 2 mean: 94.896
#           Execution time: 0:00:02
#           Execution time (seconds): 2.44

# %% [markdown]
# ### Normals with mean in 100 and 85

# %%
c = np.random.normal(85, 5, 1000)

# %%
fig = plt.figure(figsize=(8, 2))
plt.hist(c, bins=50, color=alpha_color(palette[3], 0.85));
plt.xlim(70, 120)
axis_rstyle()
plt.show()
savefig('e', dir=dir_save_img)
# Out:
# Images 'e.png' and 'e.svg' successfully saved into 'img/' directory

# %%
test_poisson_bootstrap(
    data1=a,
    data2=c,
    colors=[palette[1], palette[3]])
# Out:
#           Significantly difference:              True              Lower Boundary:       6.964
#           Means Differences' distribution:     normal              Means Difference:    15.092
#           Kolmogorov–Smirnov test p-value:      0.922              Upper Boundary:      23.108
#
#           ====================================================================================
#
#           Sample 1 mean: 99.902
#           Sample 2 mean: 84.810
#           Execution time: 0:00:03
#           Execution time (seconds): 2.93

# %% [markdown]
# ### Normals with mean in 100 and 95 with 5000 elements

# %%
d = np.random.normal(100, 5, 5000)

# %%
fig = plt.figure(figsize=(8, 2))
plt.hist(d, bins=50, color=palette[1]);
plt.xlim(70, 120)
axis_rstyle()
plt.show()
savefig('c', dir=dir_save_img)
# Out:
# Images 'c.png' and 'c.svg' successfully saved into 'img/' directory

# %%
e = np.random.normal(95, 5, 5000)

# %%
fig = plt.figure(figsize=(8, 2))
plt.hist(e, bins=50, color=palette[2]);
plt.xlim(70, 120)
axis_rstyle()
plt.show()
savefig('d', dir=dir_save_img)
# Out:
# Images 'd.png' and 'd.svg' successfully saved into 'img/' directory

# %%
test_poisson_bootstrap(
    data1=d,
    data2=e,
    colors=[palette_bright[1], palette_bright[2]])
# Out:
#           Significantly difference:              True              Lower Boundary:       1.141
#           Means Differences' distribution:     normal              Means Difference:     4.927
#           Kolmogorov–Smirnov test p-value:      0.194              Upper Boundary:       8.792
#
#           ====================================================================================
#
#           Sample 1 mean: 100.000
#           Sample 2 mean: 95.072
#           Execution time: 0:00:10
#           Execution time (seconds): 10.14

# %% [markdown]
# ### Execution time

# %%
stopwatch_stop(start)
# Out:
# Execution time: 0:00:37
